// %%
%classpath add jar ../Jupyter_tests/TestProcessing/ProcessingForJupyter.jar

// %%
import processingforjupyter.ProcessingForJupyter;
ProcessingForJupyter a=new ProcessingForJupyter();
a.run();
Thread.sleep(4000);
a.getFrame();
